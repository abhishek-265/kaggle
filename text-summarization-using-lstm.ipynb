# %% [markdown]
# # ***Adding requirement for attention layer***

# %%
from shutil import copyfile
copyfile(src = "../input/attention/attention.py", dst = "../working/attention.py")
# Out:
# '../working/attention.py'

# %% [markdown]
# # ***importing required libraries***

# %%
import numpy as np
import pandas as pd 
import re
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import warnings
from attention import AttentionLayer
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # ***Loading dataset to the notebook***

# %%
data=pd.read_csv("../input/amazon-fine-food-reviews/Reviews.csv")

# %% [markdown]
# # ***Dropping duplicate reviews and null values***

# %%
data.drop_duplicates(subset=['Text'],inplace=True)#dropping duplicates
data.dropna(axis=0,inplace=True)#dropping na

# %% [markdown]
# # ***Information about datatypes and shape of the dataset***

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393565 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      393565 non-null  int64
#  1   ProductId               393565 non-null  object
#  2   UserId                  393565 non-null  object
#  3   ProfileName             393565 non-null  object
#  4   HelpfulnessNumerator    393565 non-null  int64
#  5   HelpfulnessDenominator  393565 non-null  int64
#  6   Score                   393565 non-null  int64
#  7   Time                    393565 non-null  int64
#  8   Summary                 393565 non-null  object
#  9   Text                    393565 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 33.0+ MB

# %% [markdown]
# # ***Dictionary for expanding the contractions***

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

# %% [markdown]
# # ***For removing stopwords***

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# # ***Function for cleaning reviews and summaries***

# %%
def text_cleaner(text,num):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString)
    if(num==0):
        tokens = [w for w in newString.split() if not w in stop_words]
    else:
        tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

# %% [markdown]
# # ***cleaning reviews and displaying***

# %%
#call the function
cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t,0))
cleaned_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %% [markdown]
# # ***cleaning summaries and displaying***

# %%
#call the function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(text_cleaner(t,1))
cleaned_summary[:10]
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy',
#  'nice taffy',
#  'great just as good as the expensive brands',
#  'wonderful tasty taffy',
#  'yay barley',
#  'healthy dog food']

# %% [markdown]
# # ***Adding columns into the dataset***

# %%
data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary

# %% [markdown]
# # ***Dropping empty rows***

# %%
data.replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %% [markdown]
# # ***Visualization distribution of reviews and summaries***

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %%
cnt=0
for i in data['cleaned_summary']:
    if(len(i.split())<=10):
        cnt=cnt+1
print(cnt/len(data['cleaned_summary']))
# Out:
# 0.9801405345194589

# %%
cnt=0
for i in data['cleaned_text']:
    if(len(i.split())<=80):
        cnt=cnt+1
print(cnt/len(data['cleaned_text']))
# Out:
# 0.9130318682240923

# %%
max_text_len=80
max_summary_len=10

# %% [markdown]
# # ***getting rid of outliers***

# %%
cleaned_text =np.array(data['cleaned_text'])
cleaned_summary=np.array(data['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
df=pd.DataFrame({'text':short_text,'summary':short_summary})

# %% [markdown]
# # ***Adding tokens at the beginning and the end of summary***

# %%
df['summary'] = df['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
for i in range(5):
    print("Review:",df['text'][i])
    print("Summary:",df['summary'][i])
    print("\n")
# Out:
# Review: bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# Summary: sostok good quality dog food eostok
#
#
# Review: product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# Summary: sostok not as advertised eostok
#
#
# Review: confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
# Summary: sostok delight says it all eostok
#
#
# Review: looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# Summary: sostok cough medicine eostok
#
#
# Review: great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# Summary: sostok great taffy eostok

# %% [markdown]
# # ***splitting traing and test set***

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['summary']),test_size=0.05,random_state=0,shuffle=True)

# %% [markdown]
# # ***prepare a tokenizer for reviews on training data***

# %%
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %% [markdown]
# # ***calculating number of rare and common words in reviews***

# %%
thresh=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 67.98872558888665
# Total Coverage of rare words: 0.8628139196498984

# %% [markdown]
# # ***defining tokenizer with most common words for reviews***

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

# %%
x_voc
# Out:
# 30211

# %% [markdown]
# # ***prepare a tokenizer for summaries on training data***

# %%
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

# %% [markdown]
# # ***calculating number of rare and common words in summaries***

# %%
thresh=6

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 74.62702066530514
# Total Coverage of rare words: 1.8678335178852608

# %% [markdown]
# # ***defining tokenizer with most common words for summaries***

# %%
#prepare a tokenizer for summaries on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

# %% [markdown]
# # ***checking word count of start token is equal to length of the training data***

# %%
y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# (335882, 335882)

# %% [markdown]
# # ***deleting the rows that contain only START and END tokens***

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %% [markdown]
# # ***Model building, defining LSTM layers, Encoder and Decoder***

# %%
from keras import backend as K 
K.clear_session()

latent_dim = 300
embedding_dim=100

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 80, 100)      3021100     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 80, 300), (N 481200      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 80, 300), (N 721200      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 100)    733100      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 80, 300), (N 721200      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 300),  481200      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 300),  180300      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 600)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 7331)   4405931     concat_layer[0][0]
# ==================================================================================================
# Total params: 10,745,231
# Trainable params: 10,745,231
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %% [markdown]
# # ***monitoring the validation loss***

# %%
es = [EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2), 
      ModelCheckpoint('./MyModel_tf',monitor='val_loss', verbose=1,
                      save_best_only=True, mode='min', save_weights_only = False)]

# %% [markdown]
# # ***train the model on a batch size of 512 and validate it on the 10% of dataset***

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=512, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 650/650 [==============================] - ETA: 0s - loss: 2.6041
# Epoch 00001: val_loss improved from inf to 2.29002, saving model to ./MyModel_tf
# 650/650 [==============================] - 734s 1s/step - loss: 2.6041 - val_loss: 2.2900
# Epoch 2/50
# 650/650 [==============================] - ETA: 0s - loss: 2.2020
# Epoch 00002: val_loss improved from 2.29002 to 2.08512, saving model to ./MyModel_tf
# 650/650 [==============================] - 703s 1s/step - loss: 2.2020 - val_loss: 2.0851
# Epoch 3/50
# 650/650 [==============================] - ETA: 0s - loss: 2.0483
# Epoch 00003: val_loss improved from 2.08512 to 1.98308, saving model to ./MyModel_tf
# 650/650 [==============================] - 697s 1s/step - loss: 2.0483 - val_loss: 1.9831
# Epoch 4/50
# 650/650 [==============================] - ETA: 0s - loss: 1.9585
# Epoch 00004: val_loss improved from 1.98308 to 1.91908, saving model to ./MyModel_tf
# 650/650 [==============================] - 728s 1s/step - loss: 1.9585 - val_loss: 1.9191
# Epoch 5/50
# 650/650 [==============================] - ETA: 0s - loss: 1.8974
# Epoch 00005: val_loss improved from 1.91908 to 1.87946, saving model to ./MyModel_tf
# 650/650 [==============================] - 736s 1s/step - loss: 1.8974 - val_loss: 1.8795
# Epoch 6/50
# 650/650 [==============================] - ETA: 0s - loss: 1.8524
# Epoch 00006: val_loss improved from 1.87946 to 1.85096, saving model to ./MyModel_tf
# 650/650 [==============================] - 737s 1s/step - loss: 1.8524 - val_loss: 1.8510
# Epoch 7/50
# 650/650 [==============================] - ETA: 0s - loss: 1.8181
# Epoch 00007: val_loss improved from 1.85096 to 1.83112, saving model to ./MyModel_tf
# 650/650 [==============================] - 714s 1s/step - loss: 1.8181 - val_loss: 1.8311
# Epoch 8/50
# 650/650 [==============================] - ETA: 0s - loss: 1.7903
# Epoch 00008: val_loss improved from 1.83112 to 1.81509, saving model to ./MyModel_tf
# 650/650 [==============================] - 708s 1s/step - loss: 1.7903 - val_loss: 1.8151
# Epoch 9/50
# 650/650 [==============================] - ETA: 0s - loss: 1.7668
# Epoch 00009: val_loss improved from 1.81509 to 1.79804, saving model to ./MyModel_tf
# 650/650 [==============================] - 746s 1s/step - loss: 1.7668 - val_loss: 1.7980
# Epoch 10/50
# 650/650 [==============================] - ETA: 0s - loss: 1.7465
# Epoch 00010: val_loss improved from 1.79804 to 1.79013, saving model to ./MyModel_tf
# 650/650 [==============================] - 721s 1s/step - loss: 1.7465 - val_loss: 1.7901
# Epoch 11/50
# 650/650 [==============================] - ETA: 0s - loss: 1.7290
# Epoch 00011: val_loss improved from 1.79013 to 1.77940, saving model to ./MyModel_tf
# 650/650 [==============================] - 694s 1s/step - loss: 1.7290 - val_loss: 1.7794
# Epoch 12/50
# 650/650 [==============================] - ETA: 0s - loss: 1.7125
# Epoch 00012: val_loss improved from 1.77940 to 1.77157, saving model to ./MyModel_tf
# 650/650 [==============================] - 703s 1s/step - loss: 1.7125 - val_loss: 1.7716
# Epoch 13/50
# 650/650 [==============================] - ETA: 0s - loss: 1.6988
# Epoch 00013: val_loss improved from 1.77157 to 1.76917, saving model to ./MyModel_tf
# 650/650 [==============================] - 698s 1s/step - loss: 1.6988 - val_loss: 1.7692
# Epoch 14/50
# 650/650 [==============================] - ETA: 0s - loss: 1.6859
# Epoch 00014: val_loss improved from 1.76917 to 1.76022, saving model to ./MyModel_tf
# 650/650 [==============================] - 702s 1s/step - loss: 1.6859 - val_loss: 1.7602
# Epoch 15/50
# 650/650 [==============================] - ETA: 0s - loss: 1.6744
# Epoch 00015: val_loss did not improve from 1.76022
# 650/650 [==============================] - 694s 1s/step - loss: 1.6744 - val_loss: 1.7611
# Epoch 16/50
# 650/650 [==============================] - ETA: 0s - loss: 1.6638
# Epoch 00016: val_loss improved from 1.76022 to 1.75555, saving model to ./MyModel_tf
# 650/650 [==============================] - 705s 1s/step - loss: 1.6638 - val_loss: 1.7555
# Epoch 17/50
# 650/650 [==============================] - ETA: 0s - loss: 1.6546
# Epoch 00017: val_loss improved from 1.75555 to 1.75266, saving model to ./MyModel_tf
# 650/650 [==============================] - 724s 1s/step - loss: 1.6546 - val_loss: 1.7527
# Epoch 18/50
# 650/650 [==============================] - ETA: 0s - loss: 1.6457
# Epoch 00018: val_loss did not improve from 1.75266
# 650/650 [==============================] - 706s 1s/step - loss: 1.6457 - val_loss: 1.7590
# Epoch 19/50
# 650/650 [==============================] - ETA: 0s - loss: 1.6370
# Epoch 00019: val_loss did not improve from 1.75266
# 650/650 [==============================] - 702s 1s/step - loss: 1.6370 - val_loss: 1.7567
# Epoch 00019: early stopping

# %%
# serialize model to JSON
model_json = model.to_json()
with open("summary.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("summary.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # ***understanding the behavior of model over time***

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # ***convert the index to word for summaries and reviews vocabulary***

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %% [markdown]
# # ***Setting up the inference for the encoder and decoder***

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %% [markdown]
# # ***Defining a functio for implementation of the inference process***

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %% [markdown]
# # ***converting an integer sequence to a word sequence for summaries and reviews***

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %% [markdown]
# # ***displaying some summaries generated by the model***

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: happy purchase product excellent quality price fantastic get stock
# Original summary: great value
# Predicted summary:  excellent
#
#
# Review: coffee right like bold one cup morning gets going keeps going day
# Original summary: great coffee
# Predicted summary:  great coffee
#
#
# Review: years favorite cracker keebler clubs one day saw multi grain version thought would give try especially since normally enjoy whole grain breads trying lower cholesterol could believe multi grain version actually tastes better original bought several boxes crackers always make sure hand use asian tuna salad inglehoffer sweet honey mustard spreads soups tasty crackers
# Original summary: better than the original
# Predicted summary:  best cracker ever
#
#
# Review: fantastic product use every day power drink meal replacement tastes great recommended product several vegans
# Original summary: nutiva organic hemp protein lb bag
# Predicted summary:  great product
#
#
# Review: trying different water products last years last found really refreshing tasty
# Original summary: do not look anywhere else
# Predicted summary:  love this stuff
#
#
# Review: olives absolute steal based sell amazon nice size none soft herb solution comes great touch strain use mix overall great value pounds may seem like lot go every month
# Original summary: best olives for the money on amazon
# Predicted summary:  great olives
#
#
# Review: good nut bag works well matter many nuts coconut meat need extract juice easily
# Original summary: great price and great product
# Predicted summary:  good stuff
#
#
# Review: made according directions oatmeal thick nice put real maple syrup good go
# Original summary: awesome
# Predicted summary:  good stuff
#
#
# Review: special kind honey tastes different traditional lil like medicine medicinal wonders stomach issues
# Original summary: love manuka
# Predicted summary:  honey
#
#
# Review: great healthy snack chip cross mini rice cake potato chip texture right amount salt make perfect potato chip substitute potato chip addict discovered walk right past potato chips grams protein grams fat calories per bag home run bag apple make perfect breakfast run
# Original summary: tasty snack
# Predicted summary:  great chips
#
#
# Review: dogs love purina beneful original dogfood normally feed gave bowl beneful jumped small problems looks pretty good dogfood goes different shapes colors contains chicken products beef looks fine dogs eat mix canned dry fresh vegetables real meat worried nutrition say give try
# Original summary: dogs love it
# Predicted summary:  dogs love it
#
#
# Review: bit bullet got mio flavor tastes ok funky fresh aspartame kinda taste dont like diet sodas al give head aches headache took flavor add walks hikes etc mean nice keep something portable bag add want flavor water im sure whats know taste headache
# Original summary: tastes ok but
# Predicted summary:  not bad
#
#
# Review: chance check bpa content cans check additives health ranger mike adams published web list least cats eat product like texture smell taste better brands tried finicky try vary types one seems lasting little one natural value tuna albacore crab also handled amazon
# Original summary: my cats for this catfood
# Predicted summary:  cat food
#
#
# Review: eat think smile chewy granola bars okay really enjoyed granola bites decided try granola bars bars tasted good chewy felt bit stale times really enjoyed taste ingredients gnaw bar times order digest found way make bars chewy would awesome give review three stars really wanted give five bars chewy advertised
# Original summary: not very chewy but some what enjoyable
# Predicted summary:  not bad but not great
#
#
# Review: coffee well never going good something buy fresh grind canned coffee reasonable espresso machine came box individually wrapped illy ese pods dismayed quantity non recyclable waste wrappers bothers also slightly better nice reusable tin filled plain pods individually wrapped use quickly opened use infrequently box individually wrapped pods might preferable
# Original summary: decent coffee less waste than individually wrapped pods
# Predicted summary:  good coffee
#
#
# Review: amazon list cereal certified organic organic company website shows many cereal products organic use word natural means nothing ingredients natural product may laced pesticides fungicides hormones made genetically modified plants fruits vegetables barbaras corporation concerned making world better place protecting environment food conglomerates always comes profits make people think barbaras synonymous organic products start selling natural products inflated prices makes great profit margin taking advantage well ill informed consumers
# Original summary: not organic as advertised
# Predicted summary:  contains gmo
#
#
# Review: health food nut means actually went store today intending buy cap crunch stuff sale picture box showed cereal looked similar cap crunch know kashi foods tend healthier also trying save money bought cereal thinking however really expecting much pleased report though stuff really tasty really taste like cap slightly sweet pleasantly crunchy great flavor plus way fiber cap crunch probably less sugar full disclosure eat cereal dry sure would taste like milk imagine would good
# Original summary: tasty
# Predicted summary:  great taste but not the same as you
#
#
# Review: taking year possibly lowered little knows really hate taking alternative statins new product greasy even outside takes soap wash hands could glycerin called company complain taste consistency ingredients confirmed reformulation noted comments sent refund one boxes unlikely anything change reformulated sugar content taste even sweeter granular smooth shape different cares mostly put corn syrup sugar dye urge call complain said calls help finding product asked available online answer always way
# Original summary: is terrible
# Predicted summary:  do not buy this product
#
#
# Review: use treats every couple days take frig dogs go nuts say careful fingers dogs seem care chomp mine want thier treats
# Original summary: my dogs love them
# Predicted summary:  dogs love them
#
#
# Review: beans readily available regular supermarkets quite good standard large limas actual butter beans seasoning packet strong half per package beans fine
# Original summary: fine product
# Predicted summary:  good beans
#
#
# Review: generally care much healthy alternatives especially comes coffee however trying truvia hotel hooked usually get grocery store good see available amazon prime might getting online instead sweetener tastes really good addition coffee desserts tastes great think even tastes better sugar definitely tastes better splenda cannot comment health aspects related artificial sweeteners sure plenty information available internet related casual coffee drinker highly recommend truvia definitely buy smaller package first time trying
# Original summary: tastes great
# Predicted summary:  great taste
#
#
# Review: expecting like honey nut cheerios also like actually different necessarily better different nut taste sweet tasting similar cereals also make good snack dry personally found nice change taste liked quite bit son ended second dinner still hungry want desert wife however like obviously everyone buying cereal
# Original summary: tasty not too sweet
# Predicted summary:  pretty good
#
#
# Review: exceeded expectations concerned dates raisins may added sugar think healthy diet nice addition good cold probably consume every meal good dry cold milk warm almonds sliced everything small break tooth bag real bargain expiration date great shelf life enjoy
# Original summary: very healthy
# Predicted summary:  great dates
#
#
# Review: love product upon recieving cans thats said lbs im sure cans full disappointed
# Original summary: disappointed
# Predicted summary:  damaged goods
#
#
# Review: straight bella napoli best try espresso maker
# Original summary: the best coffee
# Predicted summary:  best espresso
#
#
# Review: good price way better petco dogs love one two three years old still enjoy chompers chew sticks
# Original summary: terriers love these treats they gobble them up
# Predicted summary:  dogs love them
#
#
# Review: wife celiac picky pasta tried every dried rice pasta could find tinkyada hands best texture excellent much easier cook proper al dente brand good flavor personally find fusilli form appealing indeed actually prefer pasta dried wheat based pasta heartily recommended without reservation
# Original summary: best rice pasta around
# Predicted summary:  best gluten free pasta
#
#
# Review: found local store grocery shelf much cheaper amazon really like stuff regular sparkling water
# Original summary: really like this stuff both the black and mango
# Predicted summary:  great taste
#
#
# Review: purchased bag crema aroma compare lavazza blends tried enjoyed searching coffee little bolder cut throught milk lattes cappuccinos favorite regard super crema produces little stronger espresso blend crema aroma good right makes wonderful espresso shot delightfully smooth non bitter since make mostly milk based drinks going look elsewhere richer roast
# Original summary: nice italian blend that is more smooth than bold
# Predicted summary:  lavazza espresso
#
#
# Review: hardly write reviews ironically rely purchases amazon huge amazon shopper everything buy prime waffle mix far best get disappointed fluffy soft ordered cans cousins family want use proctor waffle maker perfect also bought amazon anyone buying store bought waffle mixes must convert one
# Original summary: must buy please read
# Predicted summary:  the best waffle mix
#
#
# Review: gosh darn looks like glass jar coconut oil great product packaged glass need beg neighbor baby food jars transfer oil hope baby food still comes glass
# Original summary: coconut oil in plastic
# Predicted summary:  love it
#
#
# Review: found much cheaper place though works need buy else
# Original summary: this coffee is great
# Predicted summary:  great product but
#
#
# Review: spice appeal anise seed ground ounce jar wonderful product use recipe calling anise kind use weekly baking favorite biscotti
# Original summary: great product
# Predicted summary:  great product
#
#
# Review: bourbon rye soda make old fashioned fruit luxardo cherries move level story manhattans use premium liquor drinks premium cherries
# Original summary: makes the best old fashioned
# Predicted summary:  the best
#
#
# Review: vanilla far favorite flavor tastes like vanilla bean ice cream would never know something good body lactose free tummy friendly packed full protein post workout recovery drink could get better
# Original summary: perfect recovery drink
# Predicted summary:  vanilla vanilla
#
#
# Review: tastes absolutely store mac cheese totally natural cheese fine powder substance foil packet save money buy store brand cents sale ralph market
# Original summary: tastes like the no name store brand
# Predicted summary:  great product but not the best
#
#
# Review: received lb bag gummi time good gummi find germany look like site already ordered read another review state thing guess need fly germany real thing
# Original summary: strawberry gummi
# Predicted summary:  gummi bears
#
#
# Review: box states perfect coffee delicious smooth rich
# Original summary: very delicious
# Predicted summary:  delicious
#
#
# Review: bought whole foods year old daughter really pleased taste loves drinks three glasses day
# Original summary: best strawberry milk you can have
# Predicted summary:  great product
#
#
# Review: gluten free tried countless different boxed mac cheeses annie far best closest kraft
# Original summary: best there is
